# %%
import requests
import gzip
import pandas as pd
import networkx as nx
import sys

import ddot
from ddot import Ontology

# %%
ndex_server = 'http://test.ndexbio.org' 

# Set the NDEx server and the user account (replace with your own account)
ndex_user, ndex_pass = 'xiaoran.a.yan', 'a1l9i8f4e3'

# %%
# Download GO obo file
r = requests.get('http://purl.obolibrary.org/obo/go/go-basic.obo')
with open('go-basic.obo', 'wb') as f:
    f.write(r.content)

# Parse OBO file
ddot.parse_obo('go-basic.obo', 'go.tab', 'goID_2_name.tab', 'goID_2_namespace.tab', 'goID_2_alt_id.tab')

# Download gene-term annotations for human
r = requests.get('http://geneontology.org/gene-associations/goa_human.gaf.gz')
with open('goa_human.gaf.gz', 'wb') as f:
    f.write(r.content)

# %%
hierarchy = pd.read_table('go.tab',
                          sep='\t',
                          header=None,
                          names=['Parent', 'Child', 'Relation', 'Namespace'])
with gzip.open('goa_human.gaf.gz', 'rb') as f:
    mapping = ddot.parse_gaf(f)

# %%
go_human = Ontology.from_table(
    table=hierarchy,
    parent='Parent',
    child='Child',
    mapping=mapping,
    mapping_child='DB Object ID',
    mapping_parent='GO ID',
    add_root_name='GO:00SUPER',
    ignore_orphan_terms=True)
go_human.clear_node_attr()
go_human.clear_edge_attr()
go_human
# Out:
# WARNING: Dropping 213667 duplicate gene-term connections
# Unifying 3 roots into one super-root
# 19626 genes, 44412 terms, 287930 gene-term relations, 89326 term-term relations
# node_attributes: []
# edge_attributes: []

# %%
go_human = go_human.collapse_ontology(method='mhkramer')
if 'GO:00SUPER' not in go_human.terms: go_human.add_root('GO:00SUPER', inplace=True)
print(go_human)
# Out:
# collapse command: /home/yan30/.ddot/lib/python3.7/site-packages/ddot/alignOntology/collapseRedundantNodes /tmp/tmpwhvvee09
# 19626 genes, 20153 terms, 228993 gene-term relations, 44286 term-term relations
# node_attributes: []
# edge_attributes: []

# %%
go_descriptions = pd.read_table('goID_2_name.tab',
                                header=None,
                                names=['Term', 'Term_Description'],
                                index_col=0)
go_human.update_node_attr(go_descriptions)

go_branches = pd.read_table('goID_2_namespace.tab',
                                header=None,
                                names=['Term', 'Branch'],
                                index_col=0)
go_human.update_node_attr(go_branches)

# %%
go_human.to_table('go_human.txt')
# Out:
#             Parent       Child      EdgeType
# 0       GO:0000002  GO:0032042  Child-Parent
# 1       GO:0000003  GO:0019953  Child-Parent
# 2       GO:0000003  GO:0022414  Child-Parent
# 3       GO:0000003  GO:0032504  Child-Parent
# 4       GO:0000003  GO:0071515  Child-Parent
# 5       GO:0000012  GO:1903516  Child-Parent
# 6       GO:0000012  GO:1903518  Child-Parent
# 7       GO:0000012  GO:1903824  Child-Parent
# 8       GO:0000014  GO:1990599  Child-Parent
# 9       GO:0000018  GO:0000019  Child-Parent
# 10      GO:0000018  GO:0010569  Child-Parent
# 11      GO:0000018  GO:0045191  Child-Parent
# 12      GO:0000018  GO:0045910  Child-Parent
# 13      GO:0000018  GO:0045911  Child-Parent
# 14      GO:0000018  GO:0032208  Child-Parent
# 15      GO:0000018  GO:0010845  Child-Parent
# 16      GO:0000018  GO:0098530  Child-Parent
# 17      GO:0000018  GO:0048239  Child-Parent
# 18      GO:0000019  GO:0045950  Child-Parent
# 19      GO:0000019  GO:0045951  Child-Parent
# 20      GO:0000019  GO:0032208  Child-Parent
# 21      GO:0000022  GO:0051256  Child-Parent
# 22      GO:0000022  GO:1902846  Child-Parent
# 23      GO:0000026  GO:0004377  Child-Parent
# 24      GO:0000026  GO:0052918  Child-Parent
# 25      GO:0000026  GO:0052926  Child-Parent
# 26      GO:0000027  GO:0034463  Child-Parent
# 27      GO:0000027  GO:1902775  Child-Parent
# 28      GO:0000028  GO:0034463  Child-Parent
# 29      GO:0000028  GO:0034462  Child-Parent
# ...            ...         ...           ...
# 273249  GO:0006357      V9GYV3     Gene-Term
# 273250  GO:0014066      V9GYV3     Gene-Term
# 273251  GO:0051279      V9GYV3     Gene-Term
# 273252  GO:0043122      V9GYV3     Gene-Term
# 273253  GO:1901222      V9GYV3     Gene-Term
# 273254  GO:2001294      V9GYW3     Gene-Term
# 273255  GO:0050080      V9GYW3     Gene-Term
# 273256  GO:0005782      V9GYW3     Gene-Term
# 273257  GO:0046321      V9GYW3     Gene-Term
# 273258  GO:0006085      V9GYW3     Gene-Term
# 273259  GO:0005759      V9GYW3     Gene-Term
# 273260  GO:0005730      V9GYY5     Gene-Term
# 273261  GO:0003723      V9GYY5     Gene-Term
# 273262  GO:0016021      V9GZ13     Gene-Term
# 273263  GO:0016021      W5XKT8     Gene-Term
# 273264  GO:0007342      W5XKT8     Gene-Term
# 273265  GO:0005515      W5XKT8     Gene-Term
# 273266  GO:0097169      W6CW81     Gene-Term
# 273267  GO:0002218      W6CW81     Gene-Term
# 273268  GO:0003690      W6CW81     Gene-Term
# 273269  GO:0005515      W6CW81     Gene-Term
# 273270  GO:0035458      W6CW81     Gene-Term
# 273271  GO:0098586      W6CW81     Gene-Term
# 273272  GO:0031333      W6CW81     Gene-Term
# 273273  GO:0050718      W6CW81     Gene-Term
# 273274  GO:0006954      W6CW81     Gene-Term
# 273275  GO:0016021      X5D2U9     Gene-Term
# 273276  GO:0006955      X5D2U9     Gene-Term
# 273277  GO:0019882      X5D2U9     Gene-Term
# 273278  GO:0042613      X5D2U9     Gene-Term
#
# [273279 rows x 3 columns]

# %%
import mygene
mg = mygene.MyGeneInfo()
name = 'Human-specific Gene Ontology'

# %%
go_human_uniprot = go_human.copy()

# Write GO to file
go_human_uniprot.to_table('collapsed_go.uniprot', clixo_format=True)
go_human_uniprot.to_pickle('collapsed_go.uniprot.pkl')

url, G = go_human_uniprot.to_ndex(name='%s, %s' % (name, 'UniProt'),
                                  ndex_server=ndex_server,
                                  ndex_user=ndex_user,
                                  ndex_pass=ndex_pass,
                                  layout=None,
                                  visibility='PUBLIC')
print(url)
# Out:
# https://test.ndexbio.org/v2/network/91bd87aa-bb70-11ea-a4d3-0660b7976219

# %%
uniprot_2_symbol_df = mg.querymany(go_human.genes, scopes='uniprot', fields='symbol', species='human', as_dataframe=True)

def f(x):
    x = x['symbol']
    if len(x)==1:
        return x[0]
    else:
        return x.tolist()
uniprot_2_symbol = uniprot_2_symbol_df.dropna(subset=['symbol']).groupby('query').apply(f)
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-8000...done.
# querying 8001-9000...done.
# querying 9001-10000...done.
# querying 10001-11000...done.
# querying 11001-12000...done.
# querying 12001-13000...done.
# querying 13001-14000...done.
# querying 14001-15000...done.
# querying 15001-16000...done.
# querying 16001-17000...done.
# querying 17001-18000...done.
# querying 18001-19000...done.
# querying 19001-19626...done.
# Finished.
# 321 input query terms found dup hits:
# 	[('A0A075B6H7', 2), ('A0A075B6J1', 2), ('A0A075B6J2', 2), ('A0A075B6P5', 2), ('A0A075B6Q5', 2), ('A0
# 731 input query terms found no hit:
# 	['A0A075B734', 'A0A075B767', 'A0A087WSY4', 'A0A087WUL8', 'A0A087WUU8', 'A0A087WX78', 'A0A087X1C1', '
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.

# %%
go_human_symbol = go_human.delete(to_delete=set(go_human.genes) - set(uniprot_2_symbol.keys()))
go_human_symbol = go_human_symbol.rename(genes=uniprot_2_symbol.to_dict())
print(go_human_symbol)

# Write GO to file
go_human_symbol.to_table('collapsed_go.symbol', clixo_format=True)
go_human_symbol.to_pickle('collapsed_go.symbol.pkl')

url, G = go_human_symbol.to_ndex(name='%s, %s' % (name, 'Symbol'),
                                 ndex_server=ndex_server,
                                 ndex_user=ndex_user,
                                 ndex_pass=ndex_pass,
                                 layout=None,
                                 visibility='PUBLIC')
print(url)
# Out:
# 19021 genes, 44412 terms, 285936 gene-term relations, 89326 term-term relations
# node_attributes: ['Term_Description', 'Branch']
# edge_attributes: []
# https://test.ndexbio.org/v2/network/bd0eb3cd-bb70-11ea-a4d3-0660b7976219

# %%
go_human_symbol.to_table('go_human.txt')
# Out:
#             Parent       Child      EdgeType
# 0       GO:0000002  GO:0032042  Child-Parent
# 1       GO:0000003  GO:0019953  Child-Parent
# 2       GO:0000003  GO:0022414  Child-Parent
# 3       GO:0000003  GO:0032504  Child-Parent
# 4       GO:0000003  GO:0071515  Child-Parent
# 5       GO:0000012  GO:1903516  Child-Parent
# 6       GO:0000012  GO:1903518  Child-Parent
# 7       GO:0000012  GO:1903824  Child-Parent
# 8       GO:0000014  GO:1990599  Child-Parent
# 9       GO:0000018  GO:0000019  Child-Parent
# 10      GO:0000018  GO:0010569  Child-Parent
# 11      GO:0000018  GO:0045191  Child-Parent
# 12      GO:0000018  GO:0045910  Child-Parent
# 13      GO:0000018  GO:0045911  Child-Parent
# 14      GO:0000018  GO:0032208  Child-Parent
# 15      GO:0000018  GO:0010845  Child-Parent
# 16      GO:0000018  GO:0098530  Child-Parent
# 17      GO:0000018  GO:0048239  Child-Parent
# 18      GO:0000019  GO:0045950  Child-Parent
# 19      GO:0000019  GO:0045951  Child-Parent
# 20      GO:0000019  GO:0032208  Child-Parent
# 21      GO:0000022  GO:0051256  Child-Parent
# 22      GO:0000022  GO:1902846  Child-Parent
# 23      GO:0000026  GO:0004377  Child-Parent
# 24      GO:0000026  GO:0052918  Child-Parent
# 25      GO:0000026  GO:0052926  Child-Parent
# 26      GO:0000027  GO:0034463  Child-Parent
# 27      GO:0000027  GO:1902775  Child-Parent
# 28      GO:0000028  GO:0034463  Child-Parent
# 29      GO:0000028  GO:0034462  Child-Parent
# ...            ...         ...           ...
# 271280  GO:0005634  AC012531.3     Gene-Term
# 271281  GO:0009952  AC012531.3     Gene-Term
# 271282  GO:0033613  AC012531.3     Gene-Term
# 271283  GO:0048704  AC012531.3     Gene-Term
# 271284  GO:0000977  AC012531.3     Gene-Term
# 271285  GO:0001228  AC012531.3     Gene-Term
# 271286  GO:0019815  AL121845.2     Gene-Term
# 271287  GO:0019901  AL121845.2     Gene-Term
# 271288  GO:0050853  AL121845.2     Gene-Term
# 271289  GO:0043405  AL121845.2     Gene-Term
# 271290  GO:0006357  AL121845.2     Gene-Term
# 271291  GO:0014066  AL121845.2     Gene-Term
# 271292  GO:0051279  AL121845.2     Gene-Term
# 271293  GO:0043122  AL121845.2     Gene-Term
# 271294  GO:1901222  AL121845.2     Gene-Term
# 271295  GO:0005730    Z83844.1     Gene-Term
# 271296  GO:0003723    Z83844.1     Gene-Term
# 271297  GO:0016021  AL034430.1     Gene-Term
# 271298  GO:0016021      SPACA6     Gene-Term
# 271299  GO:0007342      SPACA6     Gene-Term
# 271300  GO:0005515      SPACA6     Gene-Term
# 271301  GO:0097169       PYDC5     Gene-Term
# 271302  GO:0002218       PYDC5     Gene-Term
# 271303  GO:0003690       PYDC5     Gene-Term
# 271304  GO:0005515       PYDC5     Gene-Term
# 271305  GO:0035458       PYDC5     Gene-Term
# 271306  GO:0098586       PYDC5     Gene-Term
# 271307  GO:0031333       PYDC5     Gene-Term
# 271308  GO:0050718       PYDC5     Gene-Term
# 271309  GO:0006954       PYDC5     Gene-Term
#
# [271310 rows x 3 columns]

# %%
"ALKBH3" in go_human_symbol.genes
# Out:
# True

# %%
import pickle

with open ('hierarchyQnew0.save', 'rb') as fp:
    itemlist = pickle.load(fp)

hierarchy  = [x for x in itemlist if "subsystem" in str(x[0])]
mapping = [x for x in itemlist if "subsystem" not in str(x[0])]

import ddot
from ddot import Ontology
# Construct ontology
ont = Ontology(hierarchy, mapping)

# Prints a summary of the ontology's structure
print(ont)
ont.to_table('toy_ontology2.txt')
# Out:
# 306 genes, 394 terms, 357 gene-term relations, 470 term-term relations
# node_attributes: []
# edge_attributes: []
#            Parent         Child      EdgeType
# 0    subsystem100   subsystem85  Child-Parent
# 1    subsystem100   subsystem88  Child-Parent
# 2    subsystem101   subsystem86  Child-Parent
# 3    subsystem101   subsystem94  Child-Parent
# 4    subsystem102   subsystem87  Child-Parent
# 5    subsystem102   subsystem93  Child-Parent
# 6    subsystem104    subsystem3  Child-Parent
# 7    subsystem104    subsystem6  Child-Parent
# 8    subsystem108   subsystem41  Child-Parent
# 9    subsystem109   subsystem95  Child-Parent
# 10   subsystem109  subsystem101  Child-Parent
# 11   subsystem111   subsystem30  Child-Parent
# 12   subsystem111   subsystem41  Child-Parent
# 13   subsystem113   subsystem41  Child-Parent
# 14   subsystem113   subsystem69  Child-Parent
# 15   subsystem116   subsystem23  Child-Parent
# 16   subsystem119   subsystem42  Child-Parent
# 17   subsystem120  subsystem105  Child-Parent
# 18   subsystem120  subsystem107  Child-Parent
# 19   subsystem120  subsystem110  Child-Parent
# 20   subsystem121  subsystem106  Child-Parent
# 21   subsystem121  subsystem108  Child-Parent
# 22   subsystem126   subsystem67  Child-Parent
# 23   subsystem127   subsystem68  Child-Parent
# 24   subsystem127   subsystem90  Child-Parent
# 25   subsystem128   subsystem68  Child-Parent
# 26   subsystem129   subsystem39  Child-Parent
# 27   subsystem129   subsystem68  Child-Parent
# 28   subsystem131    subsystem4  Child-Parent
# 29   subsystem132   subsystem96  Child-Parent
# ..            ...           ...           ...
# 797  subsystem179       TUBGCP4     Gene-Term
# 798  subsystem173       TUBGCP4     Gene-Term
# 799   subsystem88         UBE2A     Gene-Term
# 800   subsystem13         UBE2B     Gene-Term
# 801  subsystem210         UBE2I     Gene-Term
# 802   subsystem97         UBE2N     Gene-Term
# 803  subsystem351         UBE2T     Gene-Term
# 804  subsystem128        UBE2V2     Gene-Term
# 805  subsystem259          UBR7     Gene-Term
# 806  subsystem114         UIMC1     Gene-Term
# 807  subsystem136           UNG     Gene-Term
# 808  subsystem359          USP1     Gene-Term
# 809  subsystem162         USP42     Gene-Term
# 810  subsystem164          USP7     Gene-Term
# 811   subsystem28         UVSSA     Gene-Term
# 812    subsystem5          VRK1     Gene-Term
# 813  subsystem351          WDR4     Gene-Term
# 814   subsystem16         WDR48     Gene-Term
# 815  subsystem219        WRAP53     Gene-Term
# 816  subsystem364           WRN     Gene-Term
# 817   subsystem97          XAB2     Gene-Term
# 818  subsystem210           XPA     Gene-Term
# 819  subsystem139           XPC     Gene-Term
# 820  subsystem291         XRCC1     Gene-Term
# 821  subsystem381         XRCC2     Gene-Term
# 822  subsystem380         XRCC2     Gene-Term
# 823  subsystem341         XRCC3     Gene-Term
# 824  subsystem105         XRCC4     Gene-Term
# 825  subsystem349         XRCC5     Gene-Term
# 826  subsystem198         XRCC6     Gene-Term
#
# [827 rows x 3 columns]

# %%
matchers = ont.genes
matching = [s for s in matchers if any(xs in s for xs in go_human_symbol.genes)]
matching
# Out:
# ['ACD',
#  'ADNP',
#  'ALKBH2',
#  'ALKBH3',
#  'APEX1',
#  'APEX2',
#  'APLF',
#  'APTX',
#  'ATAD5',
#  'ATM',
#  'ATR',
#  'ATRIP',
#  'ATRX',
#  'BARD1',
#  'BCCIP',
#  'BLM',
#  'BRAT1',
#  'BRCA1',
#  'BRCA2',
#  'BRCC3',
#  'BRIP1',
#  'CBX3',
#  'CCNA2',
#  'CCNH',
#  'CDC45',
#  'CDC7',
#  'CDK2',
#  'CDK7',
#  'CENPK',
#  'CEP152',
#  'CETN2',
#  'CETN3',
#  'CHAF1A',
#  'CHEK1',
#  'CHEK2',
#  'CHTF18',
#  'CKS2',
#  'CLK2',
#  'CLSPN',
#  'DBF4B',
#  'DCLRE1A',
#  'DCLRE1B',
#  'DCLRE1C',
#  'DDB1',
#  'DDB2',
#  'DHX9',
#  'DMC1',
#  'DNA2',
#  'DRG1',
#  'DSCC1',
#  'DTL',
#  'DUT',
#  'EME1',
#  'EME2',
#  'ENDOV',
#  'ERCC1',
#  'ERCC2',
#  'ERCC3',
#  'ERCC4',
#  'ERCC5',
#  'ERCC6',
#  'ERCC8',
#  'EXO1',
#  'FAAP100',
#  'FAAP20',
#  'FAAP24',
#  'FAN1',
#  'FANCA',
#  'FANCB',
#  'FANCC',
#  'FANCD2',
#  'FANCE',
#  'FANCF',
#  'FANCG',
#  'FANCI',
#  'FANCL',
#  'FANCM',
#  'FEN1',
#  'GADD45A',
#  'GADD45G',
#  'GEN1',
#  'GGCT',
#  'GINS1',
#  'GINS2',
#  'GINS3',
#  'GINS4',
#  'GMPS',
#  'GTF2H1',
#  'GTF2H2',
#  'GTF2H3',
#  'GTF2H4',
#  'GTF2H5',
#  'HELQ',
#  'HLTF',
#  'HMGB1',
#  'HMGB2',
#  'HNRNPR',
#  'HNRNPUL1',
#  'HUS1',
#  'HUS1B',
#  'KIN',
#  'LIG1',
#  'LIG3',
#  'LIG4',
#  'MAD2L2',
#  'MBD4',
#  'MCM10',
#  'MCM2',
#  'MCM3',
#  'MCM4',
#  'MCM5',
#  'MCM6',
#  'MCM7',
#  'MCM8',
#  'MCMBP',
#  'MDC1',
#  'MGMT',
#  'MLH1',
#  'MLH3',
#  'MMS19',
#  'MMS22L',
#  'MNAT1',
#  'MPG',
#  'MPLKIP',
#  'MRE11',
#  'MSH2',
#  'MSH3',
#  'MSH4',
#  'MSH5',
#  'MSH6',
#  'MTBP',
#  'MUS81',
#  'MUTYH',
#  'NABP2',
#  'NARFL',
#  'NBN',
#  'NCAPD2',
#  'NCAPD3',
#  'NCAPG',
#  'NCAPG2',
#  'NCAPH',
#  'NCAPH2',
#  'NEIL1',
#  'NEIL2',
#  'NEIL3',
#  'NHEJ1',
#  'NTHL1',
#  'NUDT1',
#  'NUP188',
#  'OGG1',
#  'ORC1',
#  'ORC2',
#  'ORC5',
#  'ORC6',
#  'PALB2',
#  'PARP1',
#  'PARP2',
#  'PARP3',
#  'PARP4',
#  'PAXIP1',
#  'PCNA',
#  'PDS5A',
#  'PDS5B',
#  'PER1',
#  'PMS1',
#  'PMS2',
#  'PNKP',
#  'POLA1',
#  'POLA2',
#  'POLB',
#  'POLD1',
#  'POLD2',
#  'POLD3',
#  'POLD4',
#  'POLE',
#  'POLE2',
#  'POLE3',
#  'POLG',
#  'POLH',
#  'POLI',
#  'POLK',
#  'POLL',
#  'POLM',
#  'POLN',
#  'POLQ',
#  'POLR2D',
#  'POLR2G',
#  'POT1',
#  'PPAT',
#  'PRIM1',
#  'PRIM2',
#  'PRKDC',
#  'PRPF19',
#  'RAD1',
#  'RAD17',
#  'RAD18',
#  'RAD23A',
#  'RAD23B',
#  'RAD50',
#  'RAD51',
#  'RAD51AP1',
#  'RAD51B',
#  'RAD51C',
#  'RAD51D',
#  'RAD52',
#  'RAD54B',
#  'RAD54L',
#  'RAD9A',
#  'RBBP8',
#  'RDM1',
#  'RECQL',
#  'RECQL4',
#  'RECQL5',
#  'REV1',
#  'REV3L',
#  'RFC1',
#  'RFC2',
#  'RFC3',
#  'RFC4',
#  'RFC5',
#  'RFWD3',
#  'RIF1',
#  'RMI1',
#  'RMI2',
#  'RNF168',
#  'RNF4',
#  'RNF8',
#  'RPA1',
#  'RPA2',
#  'RPA3',
#  'RPA4',
#  'RRM2B',
#  'RRP9',
#  'SEM1',
#  'SENP1',
#  'SETMAR',
#  'SHPRH',
#  'SLF1',
#  'SLX1A',
#  'SLX1B',
#  'SLX4',
#  'SMARCA5',
#  'SMARCAD1',
#  'SMC1A',
#  'SMC2',
#  'SMC4',
#  'SMC6',
#  'SMUG1',
#  'SPATA5',
#  'SPATA5L1',
#  'SPO11',
#  'SPRTN',
#  'SSRP1',
#  'SUMO2',
#  'SUPT16H',
#  'TDG',
#  'TDP1',
#  'TDP2',
#  'TELO2',
#  'TERF2',
#  'TICRR',
#  'TIMELESS',
#  'TIPIN',
#  'TONSL',
#  'TOP1',
#  'TOP2A',
#  'TOP2B',
#  'TOP3A',
#  'TOPBP1',
#  'TP53',
#  'TP53BP1',
#  'TRA2B',
#  'TREX1',
#  'TREX2',
#  'TTF1',
#  'TUBGCP4',
#  'UBE2A',
#  'UBE2B',
#  'UBE2I',
#  'UBE2N',
#  'UBE2T',
#  'UBE2V2',
#  'UBR7',
#  'UIMC1',
#  'UNG',
#  'USP1',
#  'USP42',
#  'USP7',
#  'UVSSA',
#  'VRK1',
#  'WDR4',
#  'WDR48',
#  'WRAP53',
#  'WRN',
#  'XAB2',
#  'XPA',
#  'XPC',
#  'XRCC1',
#  'XRCC2',
#  'XRCC3',
#  'XRCC4',
#  'XRCC5',
#  'XRCC6']

# %%
len(matching)
# Out:
# 303

# %%
go_human_symbol
# Out:
# 19021 genes, 44412 terms, 285936 gene-term relations, 89326 term-term relations
# node_attributes: ['Term_Description', 'Branch']
# edge_attributes: []

# %%
ont0 = pd.read_csv('data/pearl2015.txt', sep='\t', header=None)
ont2 = Ontology.from_table(ont0)
print(ont2)
ont2.to_table('pearl2015.txt')
# Out:
# 437 genes, 74 terms, 533 gene-term relations, 74 term-term relations
# node_attributes: []
# edge_attributes: [2]
#                                  Parent                           Child  \
# 0                 Alternative mechanism                     MRN Complex
# 1                    Associated process              Checkpoint factors
# 2                    Associated process           Chromatin remodelling
# 3                    Associated process          Chromosome segregation
# 4                    Associated process                 DNA replication
# 5                    Associated process  Modulation of nucleotide pools
# 6                    Associated process                     p53 pathway
# 7                    Associated process            Telomere maintenance
# 8                    Associated process                             TLS
# 9                    Associated process    Topisomerase damage reversal
# 10                   Associated process              Ubiquitin response
# 11                                  BER                AP endonucleases
# 12                                  BER                DNA glycosylases
# 13                                  BER          LONG PATCH-BER factors
# 14                                  BER               Other BER factors
# 15                                  BER         SHORT PATCH-BER factors
# 16                   Checkpoint factors               damage in S phase
# 17                   Checkpoint factors   FPC (fork protection complex)
# 18                   Checkpoint factors                     G1-CC phase
# 19                   Checkpoint factors                 G1-S checkpoint
# 20                   Checkpoint factors                     G2-CC phase
# 21                   Checkpoint factors                 G2-M checkpoint
# 22                   Checkpoint factors      HRAD17(Rad24)- RFC complex
# 23                   Checkpoint factors        Rad17-Mec3- Ddc1 complex
# 24                   Checkpoint factors          RAD9-Hus1-Rad1 complex
# 25                   Checkpoint factors                      S-CC phase
# 26                                  DSR                        Alt-NHEJ
# 27                                  DSR     FA (Fanconi anemia pathway)
# 28                                  DSR   HR (Homologous Recombination)
# 29                                  DSR                            NHEJ
# ..                                  ...                             ...
# 577       HR (Homologous Recombination)                           UIMC1
# 578                    DNA glycosylases                             UNG
# 579        Genes with probable DDR role                            UPF1
# 580         FA (Fanconi anemia pathway)                            USP1
# 581                                 TLS                            USP1
# 582        Genes with probable DDR role                           UVRAG
# 583  TCR (Transcription coupled repair)                           UVSSA
# 584        Genes with probable DDR role                             VCP
# 585         FA (Fanconi anemia pathway)                           WDR48
# 586                                 TLS                           WDR48
# 587                         G1-CC phase                            WEE1
# 588                         G2-CC phase                            WEE1
# 589                Telomere maintenance                          WRAP53
# 590       HR (Homologous Recombination)                             WRN
# 591              LONG PATCH-BER factors                             WRN
# 592  TCR (Transcription coupled repair)                            XAB2
# 593  TCR (Transcription coupled repair)                             XPA
# 594          GGR (Global genome repair)                             XPC
# 595  TCR (Transcription coupled repair)                           XRCC1
# 596                            Alt-NHEJ                           XRCC1
# 597             SHORT PATCH-BER factors                           XRCC1
# 598                                NHEJ                           XRCC2
# 599                                NHEJ                           XRCC3
# 600                                NHEJ                           XRCC4
# 601                                NHEJ                           XRCC5
# 602                                NHEJ                           XRCC6
# 603        Genes with probable DDR role                        XRCC6BP1
# 604        Genes with probable DDR role                            YBX1
# 605        Genes with probable DDR role                          ZRANB3
# 606        Genes with probable DDR role                          ZSWIM7
#
#          EdgeType
# 0    Child-Parent
# 1    Child-Parent
# 2    Child-Parent
# 3    Child-Parent
# 4    Child-Parent
# 5    Child-Parent
# 6    Child-Parent
# 7    Child-Parent
# 8    Child-Parent
# 9    Child-Parent
# 10   Child-Parent
# 11   Child-Parent
# 12   Child-Parent
# 13   Child-Parent
# 14   Child-Parent
# 15   Child-Parent
# 16   Child-Parent
# 17   Child-Parent
# 18   Child-Parent
# 19   Child-Parent
# 20   Child-Parent
# 21   Child-Parent
# 22   Child-Parent
# 23   Child-Parent
# 24   Child-Parent
# 25   Child-Parent
# 26   Child-Parent
# 27   Child-Parent
# 28   Child-Parent
# 29   Child-Parent
# ..            ...
# 577     Gene-Term
# 578     Gene-Term
# 579     Gene-Term
# 580     Gene-Term
# 581     Gene-Term
# 582     Gene-Term
# 583     Gene-Term
# 584     Gene-Term
# 585     Gene-Term
# 586     Gene-Term
# 587     Gene-Term
# 588     Gene-Term
# 589     Gene-Term
# 590     Gene-Term
# 591     Gene-Term
# 592     Gene-Term
# 593     Gene-Term
# 594     Gene-Term
# 595     Gene-Term
# 596     Gene-Term
# 597     Gene-Term
# 598     Gene-Term
# 599     Gene-Term
# 600     Gene-Term
# 601     Gene-Term
# 602     Gene-Term
# 603     Gene-Term
# 604     Gene-Term
# 605     Gene-Term
# 606     Gene-Term
#
# [607 rows x 3 columns]

# %%
matchers = ont2.genes
matching = [s for s in matchers if any(xs in s for xs in go_human_symbol.genes)]
matching
# Out:
# ['ABL1',
#  'ACD',
#  'ACTL6A',
#  'ACTR5',
#  'ACTR8',
#  'ALKBH1',
#  'ALKBH2',
#  'ALKBH3',
#  'AMN1',
#  'ANKRD28',
#  'ANKRD44',
#  'ANKRD52',
#  'APEX1',
#  'APEX2',
#  'APLF',
#  'APTX',
#  'ARID1A',
#  'ARID1B',
#  'ARID2',
#  'ASF1A',
#  'ASF1B',
#  'ATF2',
#  'ATM',
#  'ATR',
#  'ATRIP',
#  'ATRX',
#  'ATXN3',
#  'BAP1',
#  'BARD1',
#  'BAZ1A',
#  'BAZ1B',
#  'BCAS2',
#  'BLM',
#  'BRCA1',
#  'BRCA2',
#  'BRCC3',
#  'BRD7',
#  'BRIP1',
#  'BTG2',
#  'CCDC98',
#  'CCNA1',
#  'CCNA2',
#  'CCNB1',
#  'CCNB2',
#  'CCNB3',
#  'CCND1',
#  'CCND2',
#  'CCND3',
#  'CCNE1',
#  'CCNH',
#  'CCNO',
#  'CDC25A',
#  'CDC25B',
#  'CDC5L',
#  'CDK2',
#  'CDK4',
#  'CDK7',
#  'CDKN1A',
#  'CDKN2A',
#  'CDKN2D',
#  'CETN2',
#  'CHAF1A',
#  'CHEK1',
#  'CHEK2',
#  'CHRAC1',
#  'CIB1',
#  'CLK2',
#  'CLSPN',
#  'CNOT7',
#  'COPS2',
#  'COPS3',
#  'COPS4',
#  'COPS5',
#  'COPS6',
#  'COPS7A',
#  'COPS7B',
#  'COPS8',
#  'CRY1',
#  'CRY2',
#  'CSNK1D',
#  'CSNK1E',
#  'CTC1',
#  'CUL3',
#  'CUL4A',
#  'CUL5',
#  'DAXX',
#  'DCLRE1A',
#  'DCLRE1B',
#  'DCLRE1C',
#  'DDB1',
#  'DDB2',
#  'DDX11',
#  'DKC1',
#  'DLGAP5',
#  'DMC1',
#  'DNA2',
#  'DNMT1',
#  'DNTT',
#  'DUT',
#  'EID3',
#  'EME1',
#  'EME2',
#  'ERCC1',
#  'ERCC2',
#  'ERCC3',
#  'ERCC4',
#  'ERCC5',
#  'ERCC6',
#  'ERCC8',
#  'EXO1',
#  'EYA3',
#  'FAAP100',
#  'FAAP24',
#  'FAN1',
#  'FANCA',
#  'FANCB',
#  'FANCC',
#  'FANCD2',
#  'FANCE',
#  'FANCG',
#  'FANCI',
#  'FANCL',
#  'FANCM',
#  'FEN1',
#  'GADD45A',
#  'GADD45G',
#  'GAR1',
#  'GEN1',
#  'GPS1',
#  'GTF2H1',
#  'GTF2H2',
#  'GTF2H3',
#  'GTF2H4',
#  'GTF2H5',
#  'HELQ',
#  'HES1',
#  'HFM1',
#  'HINFP',
#  'HLTF',
#  'HMGB1',
#  'HMGB2',
#  'HUS1',
#  'HUS1B',
#  'IGHMBP2',
#  'INO80',
#  'INO80C',
#  'INO80D',
#  'INO80E',
#  'IP6K3',
#  'KAT2A',
#  'KAT5',
#  'LIG1',
#  'LIG3',
#  'LIG4',
#  'MAD2L2',
#  'MBD4',
#  'MCRS1',
#  'MDC1',
#  'MDM2',
#  'MDM4',
#  'MEN1',
#  'MGMT',
#  'MLH1',
#  'MLH3',
#  'MMS19',
#  'MMS22L',
#  'MNAT1',
#  'MPG',
#  'MPLKIP',
#  'MRE11A',
#  'MSH2',
#  'MSH3',
#  'MSH4',
#  'MSH5',
#  'MSH6',
#  'MTOR',
#  'MUS81',
#  'MUTYH',
#  'MVP',
#  'MYBBP1A',
#  'NABP1',
#  'NABP2',
#  'NBN',
#  'NCAPD2',
#  'NCAPD3',
#  'NCAPG',
#  'NCAPH',
#  'NCAPH2',
#  'NEIL1',
#  'NEIL2',
#  'NEIL3',
#  'NFATC2IP',
#  'NFRKB',
#  'NHEJ1',
#  'NHP2',
#  'NOP10',
#  'NPM1',
#  'NSMCE1',
#  'NSMCE2',
#  'NSMCE4A',
#  'NTHL1',
#  'NUDT1',
#  'OBFC2B',
#  'OGG1',
#  'PALB2',
#  'PARG',
#  'PARP1',
#  'PARP3',
#  'PARP4',
#  'PARPBP',
#  'PAXIP1',
#  'PBRM1',
#  'PCNA',
#  'PDS5A',
#  'PDS5B',
#  'PER1',
#  'PER2',
#  'PER3',
#  'PIAS1',
#  'PIAS2',
#  'PIAS3',
#  'PIAS4',
#  'PIF1',
#  'PINX1',
#  'PLRG1',
#  'PMS1',
#  'PMS2',
#  'PMS2P5',
#  'PNKP',
#  'POLA1',
#  'POLB',
#  'POLD1',
#  'POLD2',
#  'POLD3',
#  'POLD4',
#  'POLE',
#  'POLE2',
#  'POLE3',
#  'POLE4',
#  'POLG',
#  'POLG2',
#  'POLH',
#  'POLI',
#  'POLK',
#  'POLL',
#  'POLM',
#  'POLN',
#  'POLQ',
#  'POLR2A',
#  'POLR2B',
#  'POLR2C',
#  'POLR2D',
#  'POLR2E',
#  'POLR2F',
#  'POLR2G',
#  'POLR2H',
#  'POLR2I',
#  'POLR2J',
#  'POLR2K',
#  'POLR2L',
#  'POT1',
#  'PPP4C',
#  'PPP4R1',
#  'PPP4R2',
#  'PPP4R4',
#  'PPP6C',
#  'PPP6R1',
#  'PPP6R2',
#  'PPP6R3',
#  'PRKCG',
#  'PRKDC',
#  'PRMT6',
#  'RAD1',
#  'RAD17',
#  'RAD18',
#  'RAD21',
#  'RAD23A',
#  'RAD23B',
#  'RAD50',
#  'RAD51',
#  'RAD51B',
#  'RAD51C',
#  'RAD51D',
#  'RAD52',
#  'RAD54B',
#  'RAD54L',
#  'RAD9A',
#  'RAD9B',
#  'RASSF7',
#  'RBBP8',
#  'RBX1',
#  'RDM1',
#  'RECQL',
#  'RECQL4',
#  'RECQL5',
#  'REV1',
#  'REV3L',
#  'RFC1',
#  'RFC2',
#  'RFC3',
#  'RFC4',
#  'RFC5',
#  'RIF1',
#  'RMI2',
#  'RNF168',
#  'RNF4',
#  'RNF8',
#  'RPA1',
#  'RPA2',
#  'RPA3',
#  'RPA4',
#  'RPAIN',
#  'RPS27L',
#  'RRM1',
#  'RRM2',
#  'RRM2B',
#  'RTEL1',
#  'RUVBL1',
#  'RUVBL2',
#  'SETMAR',
#  'SETX',
#  'SFR1',
#  'SHFM1',
#  'SHPRH',
#  'SIRT1',
#  'SLX1A',
#  'SLX1B',
#  'SLX4',
#  'SMARCA2',
#  'SMARCA4',
#  'SMARCA5',
#  'SMARCAD1',
#  'SMARCAL1',
#  'SMARCB1',
#  'SMARCC1',
#  'SMARCC2',
#  'SMARCD1',
#  'SMARCE1',
#  'SMC1A',
#  'SMC1B',
#  'SMC2',
#  'SMC3',
#  'SMC4',
#  'SMC5',
#  'SMC6',
#  'SMG6',
#  'SMUG1',
#  'SOD1',
#  'SPO11',
#  'STAG1',
#  'STAG2',
#  'SUMO1',
#  'SUMO2',
#  'SUMO3',
#  'SUMO4',
#  'SWI5',
#  'TADA3',
#  'TCEA1',
#  'TDG',
#  'TDP1',
#  'TELO2',
#  'TEN1',
#  'TEP1',
#  'TERF1',
#  'TERF2',
#  'TERF2IP',
#  'TERT',
#  'TFPT',
#  'TIMELESS',
#  'TINF2',
#  'TIPIN',
#  'TNKS',
#  'TNP1',
#  'TONSL',
#  'TOP1',
#  'TOP2A',
#  'TOP2B',
#  'TOP3A',
#  'TOP3B',
#  'TOPBP1',
#  'TP53',
#  'TP53BP1',
#  'TP73',
#  'TREX1',
#  'TREX2',
#  'TRIM28',
#  'TTI1',
#  'TTI2',
#  'TYMS',
#  'UBA1',
#  'UBA2',
#  'UBB',
#  'UBC',
#  'UBD',
#  'UBE2A',
#  'UBE2B',
#  'UBE2I',
#  'UBE2N',
#  'UBE2T',
#  'UBE2V1',
#  'UBE2V2',
#  'UIMC1',
#  'UNG',
#  'UPF1',
#  'USP1',
#  'UVRAG',
#  'UVSSA',
#  'VCP',
#  'WDR48',
#  'WEE1',
#  'WRAP53',
#  'WRN',
#  'XAB2',
#  'XPA',
#  'XPC',
#  'XRCC1',
#  'XRCC2',
#  'XRCC3',
#  'XRCC4',
#  'XRCC5',
#  'XRCC6',
#  'XRCC6BP1',
#  'YBX1',
#  'ZRANB3',
#  'ZSWIM7']

# %%
len(matching)
# Out:
# 425

# %%
matchers = ont.genes
matching = [s for s in matchers if any(xs in s for xs in ont2.genes)]
len(matching)
# Out:
# 233

# %%
[({218, 219, 220, 221, 222}, 0.5802251813002428), ({109, 111, 112, 113, 114}, 0.6067056040722213), ({192, 193, 170}, 0.6835762943989093), ({202, 127, 138}, 0.7005106393471607), ({248, 140, 247}, 0.7174214438597685), ({139, 141, 143}, 0.7297438599366777), ({232, 230, 231}, 0.7319602600860855), ({85, 86, 87}, 0.7359528143738937), ({142, 247}, 0.8489723014245765), ({264, 265}, 0.8565835752200133), ({177, 178}, 0.8597459057197241), ({168, 120}, 0.8650893417644118), ({165, 246}, 0.8719422626098627), ({50, 36}, 0.87737607502982), ({170, 171}, 0.8852184524534124), ({84, 85}, 0.8923500122737862), ({128, 132}, 0.9261346565729521), ({164, 246}, 0.9482938968281389), ({251, 252}, 0.9495998443046346), ({105, 300}, 0.9847271483003348)]
[(1, -3339724.0), (3, -3340049.0), (0, -3340576.0), (10, -3341805.0), (4, -3342391.0), (7, -3342517.0), (14, -3344757.2), (8, -3344895.5), (6, -3344945.2), (2, -3344954.5), (12, -3345258.0), (11, -3346821.5), (5, -3346951.2), (13, -3347552.0), (15, -3348224.0), (9, -3360879.8)]
